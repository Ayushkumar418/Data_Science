# %%
import numpy as np
import time

arr = np.array([1, 2, 3, 4, 5])
result = arr ** 2 # Vectorized operation
print(result) # Output: [1 4 9 16 25]
# Out:
# [ 1  4  9 16 25]

# %%
start = time.time()
print(result + 10)
end = time.time()
print("Time taken for vectorized operation:", end - start)
# Out:
# [11 14 19 26 35]
# Time taken for vectorized operation: 0.0
