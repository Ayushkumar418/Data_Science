# %%
# Using list comprehension to add two large lists element-wise and measuring the time taken.
import time

size = 1_000_000
l1 = list(range(size))
l2 = list(range(size))

# start = time.time()
# add = [x + y for x, y in zip(l1, l2)]
# end = time.time()
# print(add[0:10])
# print(f"List comprehension took {end - start:.6f} seconds.")

start = time.time()
list = [x ** 2 for x in l1]
end = time.time()
print(f"List comprehension took {end - start:.6f} seconds.")
# Out:
# List comprehension took 0.141389 seconds.

# %%
# Using numpy arrays to add two large lists element-wise and measuring the time taken.
import numpy as np
import time

size = 1_000_000
l1 = np.array(range(size))
# l2 = np.array(list(range(size)))

# start = time.time()
# add = l1 + l2
# end = time.time()
# print(add[0:10])
# print(f"List comprehension took {end - start:.6f} seconds.")

start = time.time()
numpy_array = l1 ** 2
end = time.time()
print(f"Numpy array operation took {end - start:.6f} seconds.")
# Out:
# Numpy array operation took 0.001997 seconds.

# %% [markdown]
# ### Memory Efficiency

# %%
import sys
list_data = list(range(10))
numpy_data = np.array(list_data)

print(f"list size: {sys.getsizeof(list_data)} bytes")
print(f"numpy array size: {numpy_data.nbytes} bytes")
# Out:
# list size: 136 bytes
# numpy array size: 40 bytes
